# %% [markdown]
# <a href="https://colab.research.google.com/github/keithmonreal/FTW/blob/master/CRUD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import pandas as pd

names = []
scores = []
qanda = {}

#set questions
questions = ["A sneeze is faster than an eye blink",
              "Olympic gold medal is made of silver",
              "Chocolate is lethal to dogs.",
              "Shrimp's heart is in its head.",
              "Pigs cannot look up into the sky."] 

#set the right answers
right_answers = ["T","T","T","T","T"]

#save questions and answers in a dictionary
def qanda_dict():
  for key in questions: 
    for value in right_answers: 
      qanda[key] = value  
      break

#save the qanda dictionary in a csvfile
def qanda_csv():
  with open('qanda.csv', 'w') as csv_file:  
    writer = csv.writer(csv_file)
    for key, value in qanda.items():
        writer.writerow([key, value])
  qanda_csvfile = pd.read_csv('qanda.csv', header = None)
  qanda_csvfile.columns=["Question", "Answer"]
  qanda_csvfile.to_csv("qanda.csv")

qanda_dict()
qanda_csv()

#last_question
def last_question(names, scores, answers, score, name):
      
      print("Your answers are" + " " + str(answers)) 
      
      score = score/noquestions
      if score > 0.60:
        print("Congratulations! You passed!")
      else:
        print("You failed. It's okay, they are useless facts anyway.")
      score = "{:.2%}".format(score)
      print("\nYour score is" + " " + str(score))
      
      names.append(name)
      scores.append(score)
      
def play():

    print("\nWhat is your name\n")
    name = input("\nPlease write your name here\n")
    print("\nHi" + " " + str(name) + " " + "!" + " " + "Here is your first question.")

    #initialize the variables that will be used
    answers = []
    question_number = 0
    score = 0
    noquestions = len(questions)
  
    #while loop for the question proper
    while question_number < noquestions:
        print("\n" + str(questions[question_number]))
        answer_n = input("\nT or F \n")
        answers.append(answer_n)
        if answers[question_number] == right_answers[question_number]:
          score = score + 1
        question_number = question_number + 1
        if question_number == noquestions:
          last_question(names, scores, answers, score, name)

    print("Return to the main menu?")
    q = input("[1]Return\n[2]Quit\n")
    if "1" in str(q):
      home()
    else:
      print("Goodbye!")

def records(): 

  if len(names) > 10:
    print(names[-10:])
    print(scores[-10:])
  else:
    print("Sorry, we don't have enough players yet") 
   
  print("Return to the main menu?")
  q = input("[1]Return\n[2]Quit\n")
  if "1" in str(q):
    home()
  else:
    print("Goodbye!")

def addquestions(): 

  question = input("True or False question\n")
  questions.append(question)

  right_answer = input("Answer: T or F\n")
  right_answers.append(right_answer)
  
  print(questions)
  print(right_answers)

  qanda_dict()
  qanda_csv()
  print("The questionnaire was already saved in qanda.csv")
  qanda_csvfile = pd.read_csv('qanda.csv')
  print(qanda_csvfile)

  addanother()

def addanother():
  print("Add another question?")
  yn1 = input("Yes or No?")

  if "Yes" in str(yn1):
    addquestions() 
  else:
    print("done adding the questions" + "There is a total of" + str(noquestions) + " questions")
    
    print("Return to the main menu?")
    q = input("[1]Return\n[2]Quit\n")
    if "1" in str(q):
      home()
    else:
      print("Goodbye!")

def deleteanother():
  
  print("Delete another question?")
  yn1 = input("Yes or No?")

  if "Yes" in str(yn1):
    delquestions() 
  else:
    print("Done deleting questions" + "There is a total of" + str(noquestions) + " questions")
    
    print("Return to the main menu?")
    q = input("[1]Return\n[2]Quit\n")
    if "1" in str(q):
      home()
    else:
      print("Goodbye!")

def delquestions():
  print("Here are the questions and respective right answers\n")
  
  index = list(range(1, (len(questions) + 1)))
  print(index)
  global qanda
  print(qanda)

  print("What question number would you like to delete?")
  deleteno = input("Input question number\n") 
  deleteno = int(deleteno) - 1

  questions.pop(int(deleteno))
  right_answers.pop(int(deleteno))

  qanda = {}
  qanda_dict()
  qanda_csv()
  print("The questionnaire was already saved in qanda.csv")
  qanda_csvfile = pd.read_csv('qanda.csv')
  print(qanda_csvfile)

  index = list(range(1, (len(questions) + 1)))

  deleteanother()

def home():

  print("\nWhat do you like to do?\n")
  activity = input("[1]Add Questions\n[2]Delete Questions\n[3]Play\n[4]See Last 10 Records\n[5]Main Menu\n[6]Quit\n")
  
  if '1' in str(activity):
    addquestions()
  elif '2' in str(activity):
    delquestions()
  elif '3' in str(activity):
    play()
  elif '4' in str(activity):
    records()
  elif '5' in str(activity):
    home()
  else:
    print("Goodbye!")

home()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     490         """
# --> 491         parts = [self.recv(flags, copy=copy, track=track)]
#     492         # have first part already, only loop while more to receive
#
# ...
